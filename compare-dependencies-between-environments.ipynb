# %% [markdown]
# To compare packages between conda environments:
#
# ```conda compare environment.yml```
#
# ```conda compare -n myenv path/to/file/environment.yml```
