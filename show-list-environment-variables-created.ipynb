# %% [markdown]
# To show list of environment variables created:
#
# ```conda info --system/-s``` (list all environment variables)
#
# ```conda info --all/-a``` (list all info)
#
# ```conda info --envs/-e``` (list all environments)
