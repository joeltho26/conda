# %% [markdown]
# To export environments:
#
# ```conda export —-format=environment-yaml```
#
# ```conda export —-file=environment.yaml```
#
# ```conda export``` (exports default to yaml)
