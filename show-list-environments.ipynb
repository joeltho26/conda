# %% [markdown]
# To show list of environments created:
#
# ```conda info --envs/-e```
#
# ```conda env list```
#
# ```conda search —-envs```
#
# Params:
# - ```—-envs``` : search all of current user environments
